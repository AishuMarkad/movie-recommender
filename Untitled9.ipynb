# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Simple movie dataset
data = {
    'Movie': ['Avengers', 'Iron Man', 'Thor', 'Hulk', 'Captain America'],
    'Action': [1, 1, 1, 1, 1],
    'Comedy': [1, 0, 0, 0, 0],
    'SciFi': [1, 1, 1, 0, 1]
}

df = pd.DataFrame(data)

# Similarity calculate
features = df[['Action', 'Comedy', 'SciFi']]
similarity = cosine_similarity(features)

# Function for recommendation
def recommend(movie_name):
    movie_index = df[df['Movie'] == movie_name].index[0]
    scores = list(enumerate(similarity[movie_index]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    print("Recommended Movies:")
    for i in scores[1:4]:
        print(df.iloc[i[0]]['Movie'])

movie = input("Enter movie name: ")
recommend(movie)
# Out:
# Enter movie name:  Thor
# Recommended Movies:
# Thor
# Captain America
# Avengers

# %%
import os
print(os.listdir())
# Out:
# ['.android', '.copilot', '.gradle', '.ipynb_checkpoints', '.ipython', '.jupyter', '.mcc', '.mchp_packs', '.mplabcomm', '.mplab_scripts', '.ms-ad', '.vscode', '.vscode-shared', '1NPDPRO5.DOC', 'AndroidStudioProjects', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Documents', 'Downloads', 'Favorites', 'hello.c', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'movies.csv', 'MPLABXProjects', 'My Documents', 'myenv', 'NetHood', 'node_modules', 'NPProt.exe', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{ccb832a3-5db0-11f1-a768-d32be5e86f45}.TM.blf', 'NTUSER.DAT{ccb832a3-5db0-11f1-a768-d32be5e86f45}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{ccb832a3-5db0-11f1-a768-d32be5e86f45}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'package-lock.json', 'package.json', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'vscode-remote-wsl']

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Load dataset
movies = pd.read_csv('movies.csv')

# Use genres as features
movies['genres']=movies['genres'].fillna('')
movies['genres'] = movies['genres'].str.replace('|', ' ')

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

matrix = cv.fit_transform(movies['genres'])

# Similarity
similarity = cosine_similarity(matrix)

# Recommendation function
def recommend(movie_name):
    movie_name = movie_name.lower()
    movies['title_lower'] = movies['title'].str.lower()

    if movie_name not in movies['title_lower'].values:
        print("Movie not found 😢")
        return

    idx = movies[movies['title_lower'] == movie_name].index[0]
    scores = list(enumerate(similarity[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    print("\nRecommended Movies:")
    for i in scores[1:6]:
        print(movies.iloc[i[0]]['title'])

# Input
movie = input("Enter movie name: ")
recommend(movie)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[6], line 13
#      10 from sklearn.feature_extraction.text import CountVectorizer
#      11 cv = CountVectorizer()
# ---> 13 matrix = cv.fit_transform(movies['genres'])
#      15 # Similarity
#      16 similarity = cosine_similarity(matrix)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:1377, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1369             warnings.warn(
#    1370                 "Upper case characters found in"
#    1371                 " vocabulary while 'lowercase'"
#    1372                 " is True. These entries will not"
#    1373                 " be matched with any documents"
#    1374             )
#    1375             break
# -> 1377 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1379 if self.binary:
#    1380     X.data.fill(1)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:1264, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1262 for doc in raw_documents:
#    1263     feature_counter = {}
# -> 1264     for feature in analyze(doc):
#    1265         try:
#    1266             feature_idx = vocabulary[feature]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:99, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      77 """Chain together an optional series of text processing steps to go from
#      78 a single document to ngrams, with or without tokenizing or preprocessing.
#      79
#    (...)     95     A sequence of tokens, possibly with pairs, triples, etc.
#      96 """
#      98 if decoder is not None:
# ---> 99     doc = decoder(doc)
#     100 if analyzer is not None:
#     101     doc = analyzer(doc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:232, in _VectorizerMixin.decode(self, doc)
#     229     doc = doc.decode(self.encoding, self.decode_error)
#     231 if doc is np.nan:
# --> 232     raise ValueError(
#     233         "np.nan is an invalid document, expected byte or unicode string."
#     234     )
#     236 return doc
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# Load dataset
movies = pd.read_csv('movies.csv')

# Genres clean kar
movies['genres'] = movies['genres'].fillna('')
movies['genres'] = movies['genres'].str.replace('|', ' ')

# Convert text to numbers
cv = CountVectorizer()
matrix = cv.fit_transform(movies['genres'])

# Similarity calculate
similarity = cosine_similarity(matrix)

# Recommendation function
def recommend(movie_name):
    movie_name = movie_name.lower()
    movies['title_lower'] = movies['title'].str.lower()

    if movie_name not in movies['title_lower'].values:
        print("Movie not found 😢")
        return

    idx = movies[movies['title_lower'] == movie_name].index[0]
    scores = list(enumerate(similarity[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    print("\nRecommended Movies:")
    for i in scores[1:6]:
        print(movies.iloc[i[0]]['title'])

# Input from user
movie = input("Enter movie name: ")
recommend(movie)
# Out:
# Enter movie name:  Avatar
# Recommended Movies:
# Superman Returns
# Man of Steel
# X-Men: Days of Future Past
# Jupiter Ascending
# The Wolverine

# %%
print(movies['title'].head(10))
# Out:
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# 3                       The Dark Knight Rises
# 4                                 John Carter
# 5                                Spider-Man 3
# 6                                     Tangled
# 7                     Avengers: Age of Ultron
# 8      Harry Potter and the Half-Blood Prince
# 9          Batman v Superman: Dawn of Justice
# Name: title, dtype: object

# %%
def recommend(movie_name):
    movie_index = movies[movies['title'] == movie_name].index[0]

    distances = similarity[movie_index]

    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]
    recommended_movies = []
    for i in movie_list:
        recommended_movies.append(movies.iloc[i[0]].title)

    return recommended_movies
